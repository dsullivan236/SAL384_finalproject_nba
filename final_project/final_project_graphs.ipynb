# %%
import pandas as pd
import numpy as np
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import matplotlib.pyplot as plt
# %matplotlib notebook
import seaborn as sns

# %%
full_clean = pd.read_csv("full_updated.csv")
full_clean = full_clean.drop(columns = ['Unnamed: 0.4','Unnamed: 0.3', 'Unnamed: 0.2', 'Unnamed: 0.1', 
                                       'Unnamed: 0','Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10'])
full_clean
# Out:
#                  Player College_Conference          College  College_PPG  \
# 0           Bam Adebayo                SEC         Kentucky         13.0
# 1          Bradley Beal                SEC          Florida         14.8
# 2      Patrick Beverley                SEC         Arkansas         13.0
# 3          Devin Booker                SEC         Kentucky         10.0
# 4    Brandon Boston Jr.                SEC         Kentucky         11.5
# ..                  ...                ...              ...          ...
# 339    Lindy Waters III             Big 12   Oklahoma State          5.7
# 340      Andrew Wiggins             Big 12           Kansas         17.1
# 341   Lindell Wigginton             Big 12       Iowa State         16.4
# 342    Kenrich Williams             Big 12  Texas Christian         14.6
# 343          Trae Young             Big 12         Oklahoma         27.4
#
#      NBA_Team  NBA_PPG
# 0        Heat     14.7
# 1     Wizards     22.1
# ...

# %%
full_clean['acc_nba_ppg_average'] = full_clean.loc[full_clean['College_Conference'] == 'ACC', 'NBA_PPG'].mean()
full_clean['sec_nba_ppg_average'] = full_clean.loc[full_clean['College_Conference'] == 'SEC', 'NBA_PPG'].mean()
full_clean['big12_nba_ppg_average'] = full_clean.loc[full_clean['College_Conference'] == 'Big 12', 'NBA_PPG'].mean()
full_clean['big10_nba_ppg_average'] = full_clean.loc[full_clean['College_Conference'] == 'Big Ten', 'NBA_PPG'].mean()
full_clean['pac12_nba_ppg_average'] = full_clean.loc[full_clean['College_Conference'] == 'Pac 12', 'NBA_PPG'].mean()
full_clean.head()
# Order of highest PPG scorers in the NBA by conference
# pac 12
# sec
# big 12
# acc
# big 10
# Out:
#                Player College_Conference   College  College_PPG  NBA_Team  \
# 0         Bam Adebayo                SEC  Kentucky         13.0      Heat
# 1        Bradley Beal                SEC   Florida         14.8   Wizards
# 2    Patrick Beverley                SEC  Arkansas         13.0     Bulls
# 3        Devin Booker                SEC  Kentucky         10.0      Suns
# 4  Brandon Boston Jr.                SEC  Kentucky         11.5  Clippers
#
#    NBA_PPG  acc_nba_ppg_average  sec_nba_ppg_average  big12_nba_ppg_average  \
# 0     14.7             9.522222             9.944304               9.854167
# 1     22.1             9.522222             9.944304               9.854167
# 2      8.5             9.522222             9.944304               9.854167
# 3     23.9             9.522222             9.944304               9.854167
# 4      6.7             9.522222             9.944304               9.854167
#
#    big10_nba_ppg_average  pac12_nba_ppg_average
# ...

# %%
plt.scatter(full_clean.College_Conference, full_clean.NBA_PPG)
plt.title('PPG by College Conference')
plt.xlabel('College_Conference')
plt.ylabel('NBA_PPG')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'PPG by College Conference')
# Text(0.5, 0, 'College_Conference')
# Text(0, 0.5, 'NBA_PPG')

# %%
plt.scatter(full_clean.College_PPG, full_clean.NBA_PPG, color = 'r')
plt.title('College_PPG v NBA_PPG')
plt.xlabel('College_PPG')
plt.ylabel('NBA_PPG')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'College_PPG v NBA_PPG')
# Text(0.5, 0, 'College_PPG')
# Text(0, 0.5, 'NBA_PPG')

# %%
plt.hist(full_clean.College_PPG, bins=20, color='green')
plt.title('Histogram of College PPG')
plt.xlabel('College PPG')
plt.ylabel('count')
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([ 3.,  2.,  4., 12., 16., 36., 45., 43., 39., 46., 32., 28., 12.,
#          9.,  9.,  1.,  4.,  1.,  1.,  1.]),
#  array([ 1.9  ,  3.175,  4.45 ,  5.725,  7.   ,  8.275,  9.55 , 10.825,
#         12.1  , 13.375, 14.65 , 15.925, 17.2  , 18.475, 19.75 , 21.025,
#         22.3  , 23.575, 24.85 , 26.125, 27.4  ]),
#  <BarContainer object of 20 artists>)
# Text(0.5, 1.0, 'Histogram of College PPG')
# Text(0.5, 0, 'PPG')
# Text(0, 0.5, 'count')

# %%
plt.hist(full_clean.NBA_PPG, bins=20, color='purple')
plt.title('Histogram of NBA PPG')
plt.xlabel('NBA PPG')
plt.ylabel('count')
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([14., 25., 21., 35., 42., 48., 28., 23., 20., 16., 14., 18., 13.,
#          7.,  4.,  3.,  4.,  4.,  3.,  2.]),
#  array([ 0.8  ,  2.125,  3.45 ,  4.775,  6.1  ,  7.425,  8.75 , 10.075,
#         11.4  , 12.725, 14.05 , 15.375, 16.7  , 18.025, 19.35 , 20.675,
#         22.   , 23.325, 24.65 , 25.975, 27.3  ]),
#  <BarContainer object of 20 artists>)
# Text(0.5, 1.0, 'Histogram of NBA PPG')
# Text(0.5, 0, 'NBA PPG')
# Text(0, 0.5, 'count')
