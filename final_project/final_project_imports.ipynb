# %%
# how will a player's scoring output translate from their college conference to the NBA

# %%
# %pwd
# Out:
# '/Users/dillonsullivan/Desktop/Syracuse Academics/2023 SPRING/SAL 384/final_project'

# %%
import pandas as pd
import numpy as np
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import matplotlib.pyplot as plt
# %matplotlib notebook
import seaborn as sns

# %%
# the next few cells are importing csvs taken from realgm website and ppg comes from bball ref
sec_players = pd.read_csv("sec_players.csv")
sec_players = sec_players.drop(columns = ['Unnamed: 5','Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8'])
sec_players.tail()
# Out:
#              Player College_Conference    College  College_PPG       NBA_Team
# 74  P.J. Washington                SEC   Kentucky         12.9        Hornets
# 75  Trendon Watford                SEC        LSU         14.9  Trail Blazers
# 76   Grant Williams                SEC  Tennessee         15.7        Celtics
# 77  Jaylin Williams                SEC   Arkansas          7.9        Thunder
# 78  Robert Williams                SEC  Texas A&M         11.1        Celtics

# %%
big10_players = pd.read_csv("big10_players.csv")
big10_players = big10_players.drop(columns = ['Unnamed: 5','Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8'])
big10_players.head()
# Out:
#              Player College_Conference     College  College_PPG NBA_Team
# 0        OG Anunoby            Big Ten     Indiana          6.8  Raptors
# 1     Dalano Banton            Big Ten    Nebraska          6.3  Raptors
# 2  Keita Bates-Diop            Big Ten  Ohio State         11.7    Spurs
# 3    Malaki Branham            Big Ten  Ohio State         13.7    Spurs
# 4     Thomas Bryant            Big Ten     Indiana         12.2  Nuggets

# %%
big_12_players = pd.read_csv("big_12_players.csv")
big_12_players.head()
# Out:
#            Player College_Conference College  College_PPG   NBA_Team
# 0    Ochai Agbaji             Big 12  Kansas         12.8       Jazz
# 1   Jarrett Allen             Big 12   Texas         13.4  Cavaliers
# 2   D.J. Augustin             Big 12   Texas         14.4    Rockets
# 3  Udoka Azubuike             Big 12  Kansas         12.3       Jazz
# 4   Mohamed Bamba             Big 12   Texas         12.9     Lakers

# %%
big_east_players = pd.read_csv("Big_East_Players.csv")
big_east_players.head()
# Out:
#               Player College_Conference      College  College_PPG NBA_Team
# 0         Saddiq Bey           Big East    Villanova         11.9    Hawks
# 1    James Bouknight           Big East  Connecticut         15.0  Hornets
# 2      Mikal Bridges           Big East    Villanova         11.3     Nets
# 3      Jalen Brunson           Big East    Villanova         14.4   Knicks
# 4  Julian Champagnie           Big East   St. John's         16.0    Spurs

# %%
pac_12_players = pd.read_csv("Pac_12_Players.csv")
pac_12_players.head()
# Out:
#           Player College_Conference  College  College_PPG      NBA_Team
# 0  Kyle Anderson             Pac 12     UCLA         12.2  Timberwolves
# 1  Deandre Ayton             Pac 12  Arizona         20.1          Suns
# 2     Lonzo Ball             Pac 12     UCLA         14.6         Bulls
# 3        Bol Bol             Pac 12   Oregon         21.0         Magic
# 4  Chris Boucher             Pac 12   Oregon         12.0       Raptors

# %%
acc_players = pd.read_csv("ACC_players.csv")
acc_players.head()
# Out:
#                      Player College_Conference         College  College_PPG  \
# 0  Nickeil Alexander-Walker                ACC   Virginia Tech         13.5
# 1             Grayson Allen                ACC            Duke         14.1
# 2             Jose Alvarado                ACC    Georgia Tech         13.5
# 3              Cole Anthony                ACC  North Carolina         18.5
# 4         Marvin Bagley III                ACC            Duke         21.0
#
#        NBA_Team
# 0  Timberwolves
# 1         Bucks
# 2      Pelicans
# 3         Magic
# 4       Pistons

# %%
full = pd.concat([sec_players, big10_players, acc_players, big_east_players, pac_12_players, big_12_players])
full = full.reset_index(drop=True)
full
# Out:
#                 Player College_Conference          College  College_PPG  \
# 0          Bam Adebayo                SEC         Kentucky         13.0
# 1         Bradley Beal                SEC          Florida         14.8
# 2     Patrick Beverley                SEC         Arkansas         13.0
# 3         Devin Booker                SEC         Kentucky         10.0
# 4     B.J. Boston, Jr.                SEC         Kentucky         11.5
# ..                 ...                ...              ...          ...
# 339   Lindy Waters III             Big 12   Oklahoma State          5.7
# 340     Andrew Wiggins             Big 12           Kansas         17.1
# 341  Lindell Wigginton             Big 12       Iowa State         16.4
# 342   Kenrich Williams             Big 12  Texas Christian         14.6
# 343         Trae Young             Big 12         Oklahoma         27.4
#
#      NBA_Team
# 0        Heat
# 1     Wizards
# 2       Bulls
# 3        Suns
# 4    Clippers
# ...

# %%
helium.__file__
full_clean
# Out:
# '/Users/dillonsullivan/opt/anaconda3/lib/python3.9/site-packages/helium/__init__.py'
#      Unnamed: 0              Player College_Conference          College  \
# 0             0         Bam Adebayo                SEC         Kentucky
# 1             1        Bradley Beal                SEC          Florida
# 2             2    Patrick Beverley                SEC         Arkansas
# 3             3        Devin Booker                SEC         Kentucky
# 4             4  Brandon Boston Jr.                SEC         Kentucky
# ..          ...                 ...                ...              ...
# 339         339    Lindy Waters III             Big 12   Oklahoma State
# 340         340      Andrew Wiggins             Big 12           Kansas
# 341         341   Lindell Wigginton             Big 12       Iowa State
# 342         342    Kenrich Williams             Big 12  Texas Christian
# 343         343          Trae Young             Big 12         Oklahoma
#
# ...

# %%
#testing it to make sure it works
driver = start_chrome('https://www.google.com/')
driver.execute_script('window.open('');') #javascript command
driver.switch_to.window(driver.window_handles[1]) #switch to new window
driver.get('https://www.google.com/')
press("bam adebayo basketball reference"); press(ENTER)
click(Link('Bam Adebayo Stats, Height, Weight, Position, Draft'))
time.sleep(2)
pagesource = driver.page_source
soup = BeautifulSoup(driver.page_source, 'lxml')
table = soup.find('table', {'id': 'per_game'})
ppg = table.find('tfoot').find('td', {'data-stat': 'pts_per_g'}).text

# %%
fp='/Users/dillonsullivan/Desktop/Syracuse Academics/2023 SPRING/SAL 384/final_project'
full.to_csv(fp+'/full.csv')

# %%
# just need to clean player names so that theyre the same as on the bball ref
full_clean = pd.read_csv("full_clean.csv")

# %%
# DO NOT DELETE THIS ONE
# change players names to their bball reference names
# cant do the whole thing at once bc the computer will crash
# KERNEL 1
from bs4 import BeautifulSoup
import time
from helium import *
driver = start_chrome('https://www.google.com/')
for idx, row in full_clean[0:15].iterrows():
    driver = start_chrome('https://www.google.com/')
    driver.execute_script('window.open('');') #javascript command
    driver.switch_to.window(driver.window_handles[1]) #switch to new window
    driver.get('https://www.google.com/')
    press(row.Player+" basketball reference"); press(ENTER)
    click(Link(row.Player+' Stats, Height'))
    time.sleep(4)
    pagesource = driver.page_source
    soup = BeautifulSoup(driver.page_source, 'lxml')
    table = soup.find('table', {'id': 'per_game'})
    ppg = table.find('tfoot').find('td', {'data-stat': 'pts_per_g'}).text
    print(ppg)
    full_clean.loc[idx, 'NBA_PPG'] = ppg
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
kill_browser()
# Out:
# 14.7
# 22.1
# 8.5
# 23.9
# 6.7
# 11.5
# 6.0
# 8.7
# 15.9
# 9.7
# 24.0
# 8.0
# 1.6
# 3.8

# %%
# KERNEL 2
from bs4 import BeautifulSoup
import time
from helium import *
driver = start_chrome('https://www.google.com/')
for idx, row in full_clean[15:30].iterrows():
    driver = start_chrome('https://www.google.com/')
    driver.execute_script('window.open('');') #javascript command
    driver.switch_to.window(driver.window_handles[1]) #switch to new window
    driver.get('https://www.google.com/')
    press(row.Player+" basketball reference"); press(ENTER)
    click(Link(row.Player+' Stats, Height'))
    time.sleep(4)
    pagesource = driver.page_source
    soup = BeautifulSoup(driver.page_source, 'lxml')
    table = soup.find('table', {'id': 'per_game'})
    ppg = table.find('tfoot').find('td', {'data-stat': 'pts_per_g'}).text
    print(ppg)
    full_clean.loc[idx, 'NBA_PPG'] = ppg
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
kill_browser()
# Out:
# 5.7
# 9.3
# 21.8
# 1.5
# 8.2
# 20.2
# 4.5
# 8.0
# 18.5
# 21.1
# 7.7
# 16.2
# 7.5
# 17.7
# 13.4

# %%
# KERNEL 3
full_clean = full_clean.replace("Danuel House", "Danuel House Jr.")
full_clean = full_clean.replace("Herb Jones", "Herbert Jones")
from bs4 import BeautifulSoup
import time
from helium import *
driver = start_chrome('https://www.google.com/')
for idx, row in full_clean[30:39].iterrows():
    driver = start_chrome('https://www.google.com/')
    driver.execute_script('window.open('');') #javascript command
    driver.switch_to.window(driver.window_handles[1]) #switch to new window
    driver.get('https://www.google.com/')
    press(row.Player+" basketball reference"); press(ENTER)
    click(Link(row.Player+' Stats, Height'))
    time.sleep(4)
    pagesource = driver.page_source
    soup = BeautifulSoup(driver.page_source, 'lxml')
    table = soup.find('table', {'id': 'per_game'})
    ppg = table.find('tfoot').find('td', {'data-stat': 'pts_per_g'}).text
    print(ppg)
    full_clean.loc[idx, 'NBA_PPG'] = ppg
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
kill_browser()
# Out:
# 7.7
# 7.6
# 6.2
# 6.2
# 16.5
# 5.9
# 5.2
# 9.7
# 9.2

# %%
# KERNEL 4
# need to put kevin knox in manually
from bs4 import BeautifulSoup
import time
from helium import *
driver = start_chrome('https://www.google.com/')
for idx, row in full_clean[40:50].iterrows():
    driver = start_chrome('https://www.google.com/')
    driver.execute_script('window.open('');') #javascript command
    driver.switch_to.window(driver.window_handles[1]) #switch to new window
    driver.get('https://www.google.com/')
    press(row.Player+" basketball reference"); press(ENTER)
    click(Link(row.Player+' Stats, Height'))
    time.sleep(4)
    pagesource = driver.page_source
    soup = BeautifulSoup(driver.page_source, 'lxml')
    table = soup.find('table', {'id': 'per_game'})
    ppg = table.find('tfoot').find('td', {'data-stat': 'pts_per_g'}).text
    print(ppg)
    full_clean.loc[idx, 'NBA_PPG'] = ppg
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
kill_browser()
# Out:
# 4.9
# 3.7
# 5.7
# 5.8
# 7.8
# 9.0
# 15.4
# 10.9
# 4.6
# 16.9

# %%
# KERNEL 5
from bs4 import BeautifulSoup
import time
from helium import *
driver = start_chrome('https://www.google.com/')
for idx, row in full_clean[50:65].iterrows():
    driver = start_chrome('https://www.google.com/')
    driver.execute_script('window.open('');') #javascript command
    driver.switch_to.window(driver.window_handles[1]) #switch to new window
    driver.get('https://www.google.com/')
    press(row.Player+" basketball reference"); press(ENTER)
    click(Link(row.Player+' Stats, Height'))
    time.sleep(4)
    pagesource = driver.page_source
    soup = BeautifulSoup(driver.page_source, 'lxml')
    table = soup.find('table', {'id': 'per_game'})
    ppg = table.find('tfoot').find('td', {'data-stat': 'pts_per_g'}).text
    print(ppg)
    full_clean.loc[idx, 'NBA_PPG'] = ppg
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
kill_browser()
# Out:
# 6.7
# 7.6
# 8.2
# 2.3
# 15.2
# 11.5
# 12.7
# 18.7
# 10.1
# 5.2
# 11.8
# 6.1
# 3.7
# 19.0
# 14.7

# %%
# KERNEL 6
from bs4 import BeautifulSoup
import time
from helium import *
driver = start_chrome('https://www.google.com/')
for idx, row in full_clean[65:80].iterrows():
    driver = start_chrome('https://www.google.com/')
    driver.execute_script('window.open('');') #javascript command
    driver.switch_to.window(driver.window_handles[1]) #switch to new window
    driver.get('https://www.google.com/')
    press(row.Player+" basketball reference"); press(ENTER)
    click(Link(row.Player+' Stats, Height'))
    time.sleep(4)
    pagesource = driver.page_source
    soup = BeautifulSoup(driver.page_source, 'lxml')
    table = soup.find('table', {'id': 'per_game'})
    ppg = table.find('tfoot').find('td', {'data-stat': 'pts_per_g'}).text
    print(ppg)
    full_clean.loc[idx, 'NBA_PPG'] = ppg
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
kill_browser()
# Out:
# 2.9
# 12.8
# 2.4
# 6.2
# 9.5
# 3.2
# 23.0
# 6.2
# 4.7
# 12.9
# 7.5
# 6.2
# 5.9
# 7.3
# 11.6

# %%
# KERNEL 7
# need to put Amir Coffey in manually
from bs4 import BeautifulSoup
import time
from helium import *
driver = start_chrome('https://www.google.com/')
for idx, row in full_clean[80:85].iterrows():
    driver = start_chrome('https://www.google.com/')
    driver.execute_script('window.open('');') #javascript command
    driver.switch_to.window(driver.window_handles[1]) #switch to new window
    driver.get('https://www.google.com/')
    press(row.Player+" basketball reference"); press(ENTER)
    click(Link(row.Player+' Stats, Height'))
    time.sleep(4)
    pagesource = driver.page_source
    soup = BeautifulSoup(driver.page_source, 'lxml')
    table = soup.find('table', {'id': 'per_game'})
    ppg = table.find('tfoot').find('td', {'data-stat': 'pts_per_g'}).text
    print(ppg)
    full_clean.loc[idx, 'NBA_PPG'] = ppg
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
kill_browser()
# Out:
# 3.7
# 6.5
# 10.2
# 10.1
# 3.1

# %%
# KERNEL 8
full_clean = full_clean.replace("Moussa Diabate", "Moussa Diabaté")
from bs4 import BeautifulSoup
import time
from helium import *
driver = start_chrome('https://www.google.com/')
for idx, row in full_clean[86:100].iterrows():
    driver = start_chrome('https://www.google.com/')
    driver.execute_script('window.open('');') #javascript command
    driver.switch_to.window(driver.window_handles[1]) #switch to new window
    driver.get('https://www.google.com/')
    press(row.Player+" basketball reference"); press(ENTER)
    click(Link(row.Player+' Stats, Height'))
    time.sleep(4)
    pagesource = driver.page_source
    soup = BeautifulSoup(driver.page_source, 'lxml')
    table = soup.find('table', {'id': 'per_game'})
    ppg = table.find('tfoot').find('td', {'data-stat': 'pts_per_g'}).text
    print(ppg)
    full_clean.loc[idx, 'NBA_PPG'] = ppg
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
kill_browser()
# Out:
# 14.7
# 5.8
# 2.7
# 8.7
# 3.4
# 6.1
# 16.0
# 8.7
# 14.0
# 2.2
# 11.5
# 3.8
# 12.2
# 16.3

# %%
# KERNEL 9
from bs4 import BeautifulSoup
import time
from helium import *
driver = start_chrome('https://www.google.com/')
for idx, row in full_clean[100:115].iterrows():
    driver = start_chrome('https://www.google.com/')
    driver.execute_script('window.open('');') #javascript command
    driver.switch_to.window(driver.window_handles[1]) #switch to new window
    driver.get('https://www.google.com/')
    press(row.Player+" basketball reference"); press(ENTER)
    click(Link(row.Player+' Stats, Height'))
    time.sleep(4)
    pagesource = driver.page_source
    soup = BeautifulSoup(driver.page_source, 'lxml')
    table = soup.find('table', {'id': 'per_game'})
    ppg = table.find('tfoot').find('td', {'data-stat': 'pts_per_g'}).text
    print(ppg)
    full_clean.loc[idx, 'NBA_PPG'] = ppg
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
kill_browser()
# Out:
# 16.4
# 8.8
# 4.6
# 14.1
# 5.6
# 6.6
# 5.3
# 12.2
# 12.1
# 16.9
# 6.5
# 15.8
# 3.6
# 11.1
# 7.7

# %%
# KERNEL 10
#dlo manual
from bs4 import BeautifulSoup
import time
from helium import *
driver = start_chrome('https://www.google.com/')
for idx, row in full_clean[116:130].iterrows():
    driver = start_chrome('https://www.google.com/')
    driver.execute_script('window.open('');') #javascript command
    driver.switch_to.window(driver.window_handles[1]) #switch to new window
    driver.get('https://www.google.com/')
    press(row.Player+" basketball reference"); press(ENTER)
    click(Link(row.Player+' Stats, Height'))
    time.sleep(4)
    pagesource = driver.page_source
    soup = BeautifulSoup(driver.page_source, 'lxml')
    table = soup.find('table', {'id': 'per_game'})
    ppg = table.find('tfoot').find('td', {'data-stat': 'pts_per_g'}).text
    print(ppg)
    full_clean.loc[idx, 'NBA_PPG'] = ppg
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
kill_browser()
# Out:
# 8.0
# 5.3
# 11.2
# 6.2
# 16.9
# 8.2
# 9.1
# 1.8
# 7.5
# 8.4
# 8.4
# 9.7
# 7.7
# 14.2

# %%
# KERNEL 11
from bs4 import BeautifulSoup
import time
from helium import *
driver = start_chrome('https://www.google.com/')
for idx, row in full_clean[130:145].iterrows():
    driver = start_chrome('https://www.google.com/')
    driver.execute_script('window.open('');') #javascript command
    driver.switch_to.window(driver.window_handles[1]) #switch to new window
    driver.get('https://www.google.com/')
    press(row.Player+" basketball reference"); press(ENTER)
    click(Link(row.Player+' Stats, Height'))
    time.sleep(4)
    pagesource = driver.page_source
    soup = BeautifulSoup(driver.page_source, 'lxml')
    table = soup.find('table', {'id': 'per_game'})
    ppg = table.find('tfoot').find('td', {'data-stat': 'pts_per_g'}).text
    print(ppg)
    full_clean.loc[idx, 'NBA_PPG'] = ppg
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
kill_browser()
# Out:
# 13.3
# 20.0
# 14.2
# 15.3
# 18.1
# 10.8
# 1.6
# 7.4
# 15.4
# 8.5
# 7.7
# 2.4
# 1.9
# 12.9
# 2.2

# %%
# KERNEL 12
from bs4 import BeautifulSoup
import time
from helium import *
driver = start_chrome('https://www.google.com/')
for idx, row in full_clean[145:158].iterrows():
    driver = start_chrome('https://www.google.com/')
    driver.execute_script('window.open('');') #javascript command
    driver.switch_to.window(driver.window_handles[1]) #switch to new window
    driver.get('https://www.google.com/')
    press(row.Player+" basketball reference"); press(ENTER)
    click(Link(row.Player+' Stats, Height'))
    time.sleep(4)
    pagesource = driver.page_source
    soup = BeautifulSoup(driver.page_source, 'lxml')
    table = soup.find('table', {'id': 'per_game'})
    ppg = table.find('tfoot').find('td', {'data-stat': 'pts_per_g'}).text
    print(ppg)
    full_clean.loc[idx, 'NBA_PPG'] = ppg
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
kill_browser()
# Out:
# 15.8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/q3/h7g3dwpx517bxtdhyb10cjm00000gn/T/ipykernel_27646/1622698288.py in <module>
#      10     driver.get('https://www.google.com/')
#      11     press(row.Player+" basketball reference"); press(ENTER)
# ---> 12     click(Link(row.Player+' Stats, Height'))
#      13     time.sleep(4)
#      14     pagesource = driver.page_source
#
# ~/opt/anaconda3/lib/python3.9/site-packages/helium/__init__.py in click(element)
#     290                 click(ComboBox("File type").top_left + (50, 0))
#     291 	"""
# --> 292         _get_api_impl().click_impl(element)
#     293
#     294 def doubleclick(element):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/helium/_impl/__init__.py in click_impl(self, element)
#     202                 self.require_driver().switch_to.active_element.send_keys(key)
# ...

# %%
# KERNEL 13
full_clean = full_clean.replace("James Huff", "Jay Huff")
from bs4 import BeautifulSoup
import time
from helium import *
driver = start_chrome('https://www.google.com/')
for idx, row in full_clean[158:175].iterrows():
    driver = start_chrome('https://www.google.com/')
    driver.execute_script('window.open('');') #javascript command
    driver.switch_to.window(driver.window_handles[1]) #switch to new window
    driver.get('https://www.google.com/')
    press(row.Player+" basketball reference"); press(ENTER)
    click(Link(row.Player+' Stats, Height'))
    time.sleep(4)
    pagesource = driver.page_source
    soup = BeautifulSoup(driver.page_source, 'lxml')
    table = soup.find('table', {'id': 'per_game'})
    ppg = table.find('tfoot').find('td', {'data-stat': 'pts_per_g'}).text
    print(ppg)
    full_clean.loc[idx, 'NBA_PPG'] = ppg
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
kill_browser()
# Out:
# 4.6
# 13.9
# 19.2
# 23.4
# 9.0
# 12.8
# 7.0
# 11.3
# 4.9
# 7.6
# 2.0
# 7.9
# 6.8
# 2.6
# 1.0
# 9.9
# 3.0

# %%
# KERNEL 14
full_clean = full_clean.replace("James Huff", "Jay Huff")
from bs4 import BeautifulSoup
import time
from helium import *
driver = start_chrome('https://www.google.com/')
for idx, row in full_clean[175:187].iterrows():
    driver = start_chrome('https://www.google.com/')
    driver.execute_script('window.open('');') #javascript command
    driver.switch_to.window(driver.window_handles[1]) #switch to new window
    driver.get('https://www.google.com/')
    press(row.Player+" basketball reference"); press(ENTER)
    click(Link(row.Player+' Stats, Height'))
    time.sleep(4)
    pagesource = driver.page_source
    soup = BeautifulSoup(driver.page_source, 'lxml')
    table = soup.find('table', {'id': 'per_game'})
    ppg = table.find('tfoot').find('td', {'data-stat': 'pts_per_g'}).text
    print(ppg)
    full_clean.loc[idx, 'NBA_PPG'] = ppg
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
kill_browser()
# Out:
# 8.2
# 6.0
# 8.0
# 24.6
# 1.4
# 10.5
# 7.8
# 6.6
# 17.9
# 2.7
# 8.6
# 10.3
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/common/service.py in start(self)
#      71             cmd.extend(self.command_line_args())
# ---> 72             self.process = subprocess.Popen(cmd, env=self.env,
#      73                                             close_fds=platform.system() != 'Windows',
#
# ~/opt/anaconda3/lib/python3.9/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     950
# --> 951             self._execute_child(args, executable, preexec_fn, close_fds,
# ...

# %%
# KERNEL 15
full_clean = full_clean.replace("Dennis Smith", "Dennis Smith Jr.")
from bs4 import BeautifulSoup
import time
from helium import *
driver = start_chrome('https://www.google.com/')
for idx, row in full_clean[187:197].iterrows():
    driver = start_chrome('https://www.google.com/')
    driver.execute_script('window.open('');') #javascript command
    driver.switch_to.window(driver.window_handles[1]) #switch to new window
    driver.get('https://www.google.com/')
    press(row.Player+" basketball reference"); press(ENTER)
    click(Link(row.Player+' Stats, Height'))
    time.sleep(4)
    pagesource = driver.page_source
    soup = BeautifulSoup(driver.page_source, 'lxml')
    table = soup.find('table', {'id': 'per_game'})
    ppg = table.find('tfoot').find('td', {'data-stat': 'pts_per_g'}).text
    print(ppg)
    full_clean.loc[idx, 'NBA_PPG'] = ppg
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
kill_browser()
# Out:
# 8.5
# 13.6
# 0.8
# 5.3
# 10.3
# 7.3
# 1.3
# 22.5
# 14.4
# 11.2
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /var/folders/q3/h7g3dwpx517bxtdhyb10cjm00000gn/T/ipykernel_27646/2741522882.py in <module>
#      11     driver.get('https://www.google.com/')
#      12     press(row.Player+" basketball reference"); press(ENTER)
# ---> 13     click(Link(row.Player+' Stats, Height'))
#      14     time.sleep(4)
#      15     pagesource = driver.page_source
#
# ~/opt/anaconda3/lib/python3.9/site-packages/helium/__init__.py in click(element)
#     290                 click(ComboBox("File type").top_left + (50, 0))
#     291 	"""
# --> 292         _get_api_impl().click_impl(element)
#     293
#     294 def doubleclick(element):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/helium/_impl/__init__.py in click_impl(self, element)
# ...

# %%
# KERNEL 16
full_clean = full_clean.replace("Lonnie Walker", "Lonnie Walker IV")
from bs4 import BeautifulSoup
import time
from helium import *
driver = start_chrome('https://www.google.com/')
for idx, row in full_clean[197:213].iterrows():
    driver = start_chrome('https://www.google.com/')
    driver.execute_script('window.open('');') #javascript command
    driver.switch_to.window(driver.window_handles[1]) #switch to new window
    driver.get('https://www.google.com/')
    press(row.Player+" basketball reference"); press(ENTER)
    click(Link(row.Player+' Stats, Height'))
    time.sleep(4)
    pagesource = driver.page_source
    soup = BeautifulSoup(driver.page_source, 'lxml')
    table = soup.find('table', {'id': 'per_game'})
    ppg = table.find('tfoot').find('td', {'data-stat': 'pts_per_g'}).text
    print(ppg)
    full_clean.loc[idx, 'NBA_PPG'] = ppg
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
kill_browser()
# Out:
# 9.9
# 14.6
# 5.0
# 12.6
# 1.2
# 9.0
# 9.7
# 25.8
# 8.2
# 12.4
# 14.1
# 5.1
# 13.1
# 14.3
# 9.7
# 9.1
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /var/folders/q3/h7g3dwpx517bxtdhyb10cjm00000gn/T/ipykernel_27646/2347317163.py in <module>
#      11     driver.get('https://www.google.com/')
#      12     press(row.Player+" basketball reference"); press(ENTER)
# ---> 13     click(Link(row.Player+' Stats, Height'))
#      14     time.sleep(4)
#      15     pagesource = driver.page_source
#
# ~/opt/anaconda3/lib/python3.9/site-packages/helium/__init__.py in click(element)
#     290                 click(ComboBox("File type").top_left + (50, 0))
#     291 	"""
# --> 292         _get_api_impl().click_impl(element)
#     293
#     294 def doubleclick(element):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/helium/_impl/__init__.py in click_impl(self, element)
# ...

# %%
# KERNEL 17
full_clean = full_clean.replace("David Duke", "David Duke Jr.")
from bs4 import BeautifulSoup
import time
from helium import *
driver = start_chrome('https://www.google.com/')
for idx, row in full_clean[213:220].iterrows():
    driver = start_chrome('https://www.google.com/')
    driver.execute_script('window.open('');') #javascript command
    driver.switch_to.window(driver.window_handles[1]) #switch to new window
    driver.get('https://www.google.com/')
    press(row.Player+" basketball reference"); press(ENTER)
    click(Link(row.Player+' Stats, Height'))
    time.sleep(4)
    pagesource = driver.page_source
    soup = BeautifulSoup(driver.page_source, 'lxml')
    table = soup.find('table', {'id': 'per_game'})
    ppg = table.find('tfoot').find('td', {'data-stat': 'pts_per_g'}).text
    print(ppg)
    full_clean.loc[idx, 'NBA_PPG'] = ppg
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
kill_browser()
# Out:
# 4.2
# 8.6
# 9.8
# 5.0
# 7.7
# 1.3
# 9.3
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /var/folders/q3/h7g3dwpx517bxtdhyb10cjm00000gn/T/ipykernel_27646/594400575.py in <module>
#      11     driver.get('https://www.google.com/')
#      12     press(row.Player+" basketball reference"); press(ENTER)
# ---> 13     click(Link(row.Player+' Stats, Height'))
#      14     time.sleep(4)
#      15     pagesource = driver.page_source
#
# ~/opt/anaconda3/lib/python3.9/site-packages/helium/__init__.py in click(element)
#     290                 click(ComboBox("File type").top_left + (50, 0))
#     291 	"""
# --> 292         _get_api_impl().click_impl(element)
#     293
#     294 def doubleclick(element):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/helium/_impl/__init__.py in click_impl(self, element)
# ...

# %%
# KERNEL 18
full_clean = full_clean.replace("Paul Reed Jr.", "Paul Reed")
from bs4 import BeautifulSoup
import time
from helium import *
driver = start_chrome('https://www.google.com/')
for idx, row in full_clean[220:234].iterrows():
    driver = start_chrome('https://www.google.com/')
    driver.execute_script('window.open('');') #javascript command
    driver.switch_to.window(driver.window_handles[1]) #switch to new window
    driver.get('https://www.google.com/')
    press(row.Player+" basketball reference"); press(ENTER)
    click(Link(row.Player+' Stats, Height'))
    time.sleep(4)
    pagesource = driver.page_source
    soup = BeautifulSoup(driver.page_source, 'lxml')
    table = soup.find('table', {'id': 'per_game'})
    ppg = table.find('tfoot').find('td', {'data-stat': 'pts_per_g'}).text
    print(ppg)
    full_clean.loc[idx, 'NBA_PPG'] = ppg
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
kill_browser()
# Out:
# 3.7
# 3.2
# 7.2
# 10.0
# 6.2
# 4.3
# 5.2
# 7.0
# 16.7
# 11.9
# 6.3
# 9.1
# 14.5
# 17.9
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /var/folders/q3/h7g3dwpx517bxtdhyb10cjm00000gn/T/ipykernel_27646/1987628586.py in <module>
#      11     driver.get('https://www.google.com/')
#      12     press(row.Player+" basketball reference"); press(ENTER)
# ---> 13     click(Link(row.Player+' Stats, Height'))
#      14     time.sleep(4)
#      15     pagesource = driver.page_source
#
# ~/opt/anaconda3/lib/python3.9/site-packages/helium/__init__.py in click(element)
#     290                 click(ComboBox("File type").top_left + (50, 0))
#     291 	"""
# --> 292         _get_api_impl().click_impl(element)
#     293
#     294 def doubleclick(element):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/helium/_impl/__init__.py in click_impl(self, element)
# ...

# %%
# KERNEL 19
full_clean = full_clean.replace("Troy Brown, Jr.", "Troy Brown Jr.")
from bs4 import BeautifulSoup
import time
from helium import *
driver = start_chrome('https://www.google.com/')
for idx, row in full_clean[234:250].iterrows():
    driver = start_chrome('https://www.google.com/')
    driver.execute_script('window.open('');') #javascript command
    driver.switch_to.window(driver.window_handles[1]) #switch to new window
    driver.get('https://www.google.com/')
    press(row.Player+" basketball reference"); press(ENTER)
    click(Link(row.Player+' Stats, Height'))
    time.sleep(4)
    pagesource = driver.page_source
    soup = BeautifulSoup(driver.page_source, 'lxml')
    table = soup.find('table', {'id': 'per_game'})
    ppg = table.find('tfoot').find('td', {'data-stat': 'pts_per_g'}).text
    print(ppg)
    full_clean.loc[idx, 'NBA_PPG'] = ppg
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
kill_browser()
# Out:
# 6.6
# 6.9
# 21.0
# 6.3
# 13.8
# 13.4
# 10.7
# 6.1
# 5.5
# 11.8
# 8.7
# 13.4
# 5.8
# 24.7
# 6.6
# 16.4

# %%
# KERNEL 20
#full_clean = full_clean.replace("Troy Brown, Jr.", "Troy Brown Jr.")
from bs4 import BeautifulSoup
import time
from helium import *
driver = start_chrome('https://www.google.com/')
for idx, row in full_clean[250:267].iterrows():
    driver = start_chrome('https://www.google.com/')
    driver.execute_script('window.open('');') #javascript command
    driver.switch_to.window(driver.window_handles[1]) #switch to new window
    driver.get('https://www.google.com/')
    press(row.Player+" basketball reference"); press(ENTER)
    click(Link(row.Player+' Stats, Height'))
    time.sleep(4)
    pagesource = driver.page_source
    soup = BeautifulSoup(driver.page_source, 'lxml')
    table = soup.find('table', {'id': 'per_game'})
    ppg = table.find('tfoot').find('td', {'data-stat': 'pts_per_g'}).text
    print(ppg)
    full_clean.loc[idx, 'NBA_PPG'] = ppg
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
kill_browser()
# Out:
# 8.4
# 11.3
# 4.8
# 4.8
# 3.1
# 16.5
# 20.5
# 5.1
# 16.4
# 8.5
# 16.9
# 17.3
# 16.7
# 7.1
# 9.6
# 4.7
# 8.8

# %%
# KERNEL 21
from bs4 import BeautifulSoup
import time
from helium import *
driver = start_chrome('https://www.google.com/')
for idx, row in full_clean[267:283].iterrows():
    driver = start_chrome('https://www.google.com/')
    driver.execute_script('window.open('');') #javascript command
    driver.switch_to.window(driver.window_handles[1]) #switch to new window
    driver.get('https://www.google.com/')
    press(row.Player+" basketball reference"); press(ENTER)
    click(Link(row.Player+' Stats, Height'))
    time.sleep(4)
    pagesource = driver.page_source
    soup = BeautifulSoup(driver.page_source, 'lxml')
    table = soup.find('table', {'id': 'per_game'})
    ppg = table.find('tfoot').find('td', {'data-stat': 'pts_per_g'}).text
    print(ppg)
    full_clean.loc[idx, 'NBA_PPG'] = ppg
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
kill_browser()
# Out:
# 5.7
# 15.6
# 2.4
# 14.0
# 5.0
# 9.1
# 7.9
# 6.5
# 5.1
# 8.1
# 15.3
# 7.6
# 12.0
# 6.6
# 11.0
# 5.3
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /var/folders/q3/h7g3dwpx517bxtdhyb10cjm00000gn/T/ipykernel_27646/244513434.py in <module>
#      10     driver.get('https://www.google.com/')
#      11     press(row.Player+" basketball reference"); press(ENTER)
# ---> 12     click(Link(row.Player+' Stats, Height'))
#      13     time.sleep(4)
#      14     pagesource = driver.page_source
#
# ~/opt/anaconda3/lib/python3.9/site-packages/helium/__init__.py in click(element)
#     290                 click(ComboBox("File type").top_left + (50, 0))
#     291 	"""
# --> 292         _get_api_impl().click_impl(element)
#     293
#     294 def doubleclick(element):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/helium/_impl/__init__.py in click_impl(self, element)
# ...

# %%
# KERNEL 22
#full_clean = full_clean.replace("Isaiah Stewart II", "Isaiah Stewart")
full_clean = full_clean.replace("Nikola Vucevic", "Nikola Vučević")
from bs4 import BeautifulSoup
import time
from helium import *
driver = start_chrome('https://www.google.com/')
for idx, row in full_clean[283:300].iterrows():
    driver = start_chrome('https://www.google.com/')
    driver.execute_script('window.open('');') #javascript command
    driver.switch_to.window(driver.window_handles[1]) #switch to new window
    driver.get('https://www.google.com/')
    press(row.Player+" basketball reference"); press(ENTER)
    click(Link(row.Player+' Stats, Height'))
    time.sleep(4)
    pagesource = driver.page_source
    soup = BeautifulSoup(driver.page_source, 'lxml')
    table = soup.find('table', {'id': 'per_game'})
    ppg = table.find('tfoot').find('td', {'data-stat': 'pts_per_g'}).text
    print(ppg)
    full_clean.loc[idx, 'NBA_PPG'] = ppg
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
kill_browser()
# Out:
# 9.0
# 2.2
# 19.8
# 4.6
# 17.0
# 3.9
# 3.3
# 22.4
# 11.7
# 7.2
# 3.7
# 7.2
# 6.4
# 7.9
# 12.0
# 9.5
# 3.3

# %%
# KERNEL 23
full_clean = full_clean.replace("Mohamed Bamba", "Mo Bamba")
from bs4 import BeautifulSoup
import time
from helium import *
driver = start_chrome('https://www.google.com/')
for idx, row in full_clean[300:303].iterrows():
    driver = start_chrome('https://www.google.com/')
    driver.execute_script('window.open('');') #javascript command
    driver.switch_to.window(driver.window_handles[1]) #switch to new window
    driver.get('https://www.google.com/')
    press(row.Player+" basketball reference"); press(ENTER)
    click(Link(row.Player+' Stats, Height'))
    time.sleep(4)
    pagesource = driver.page_source
    soup = BeautifulSoup(driver.page_source, 'lxml')
    table = soup.find('table', {'id': 'per_game'})
    ppg = table.find('tfoot').find('td', {'data-stat': 'pts_per_g'}).text
    print(ppg)
    full_clean.loc[idx, 'NBA_PPG'] = ppg
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
kill_browser()
# Out:
# 7.5
# 16.1
# 4.7
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /var/folders/q3/h7g3dwpx517bxtdhyb10cjm00000gn/T/ipykernel_27646/4039954104.py in <module>
#      11     driver.get('https://www.google.com/')
#      12     press(row.Player+" basketball reference"); press(ENTER)
# ---> 13     click(Link(row.Player+' Stats, Height'))
#      14     time.sleep(4)
#      15     pagesource = driver.page_source
#
# ~/opt/anaconda3/lib/python3.9/site-packages/helium/__init__.py in click(element)
#     290                 click(ComboBox("File type").top_left + (50, 0))
#     291 	"""
# --> 292         _get_api_impl().click_impl(element)
#     293
#     294 def doubleclick(element):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/helium/_impl/__init__.py in click_impl(self, element)
#     202                 self.require_driver().switch_to.active_element.send_keys(key)
# ...

# %%
# KERNEL 24
full_clean = full_clean.replace("Mohamed Bamba", "Mo Bamba")
from bs4 import BeautifulSoup
import time
from helium import *
driver = start_chrome('https://www.google.com/')
for idx, row in full_clean[303:315].iterrows():
    driver = start_chrome('https://www.google.com/')
    driver.execute_script('window.open('');') #javascript command
    driver.switch_to.window(driver.window_handles[1]) #switch to new window
    driver.get('https://www.google.com/')
    press(row.Player+" basketball reference"); press(ENTER)
    click(Link(row.Player+' Stats, Height'))
    time.sleep(4)
    pagesource = driver.page_source
    soup = BeautifulSoup(driver.page_source, 'lxml')
    table = soup.find('table', {'id': 'per_game'})
    ppg = table.find('tfoot').find('td', {'data-stat': 'pts_per_g'}).text
    print(ppg)
    full_clean.loc[idx, 'NBA_PPG'] = ppg
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
kill_browser()
# Out:
# 1.5
# 4.1
# 5.4
# 17.8
# 27.3
# 27.2
# 11.6
# 19.0
# 16.2
# 7.5
# 16.1
# 9.8

# %%
# KERNEL 25
#full_clean = full_clean.replace("Mohamed Bamba", "Mo Bamba")
from bs4 import BeautifulSoup
import time
from helium import *
driver = start_chrome('https://www.google.com/')
for idx, row in full_clean[315:330].iterrows():
    driver = start_chrome('https://www.google.com/')
    driver.execute_script('window.open('');') #javascript command
    driver.switch_to.window(driver.window_handles[1]) #switch to new window
    driver.get('https://www.google.com/')
    press(row.Player+" basketball reference"); press(ENTER)
    click(Link(row.Player+' Stats, Height'))
    time.sleep(4)
    pagesource = driver.page_source
    soup = BeautifulSoup(driver.page_source, 'lxml')
    table = soup.find('table', {'id': 'per_game'})
    ppg = table.find('tfoot').find('td', {'data-stat': 'pts_per_g'}).text
    print(ppg)
    full_clean.loc[idx, 'NBA_PPG'] = ppg
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
kill_browser()
# Out:
# 2.7
# 7.1
# 3.0
# 8.3
# 5.8
# 8.5
# 12.3
# 10.6
# 10.5
# 6.6
# 6.5
# 6.6
# 12.8
# 10.4
# 10.2
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# /var/folders/q3/h7g3dwpx517bxtdhyb10cjm00000gn/T/ipykernel_27646/2311993482.py in <module>
#      19     print(ppg)
#      20     full_clean.loc[idx, 'NBA_PPG'] = ppg
# ---> 21     driver.close()
#      22     driver.switch_to.window(driver.window_handles[0])
#      23 kill_browser()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in close(self)
#     686             driver.close()
#     687         """
# --> 688         self.execute(Command.CLOSE)
#     689
#     690     def quit(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
# ...

# %%
# KERNEL 26
#full_clean = full_clean.replace("Mohamed Bamba", "Mo Bamba")
from bs4 import BeautifulSoup
import time
from helium import *
driver = start_chrome('https://www.google.com/')
for idx, row in full_clean[330:337].iterrows():
    driver = start_chrome('https://www.google.com/')
    driver.execute_script('window.open('');') #javascript command
    driver.switch_to.window(driver.window_handles[1]) #switch to new window
    driver.get('https://www.google.com/')
    press(row.Player+" basketball reference"); press(ENTER)
    click(Link(row.Player+' Stats, Height'))
    time.sleep(4)
    pagesource = driver.page_source
    soup = BeautifulSoup(driver.page_source, 'lxml')
    table = soup.find('table', {'id': 'per_game'})
    ppg = table.find('tfoot').find('td', {'data-stat': 'pts_per_g'}).text
    print(ppg)
    full_clean.loc[idx, 'NBA_PPG'] = ppg
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
kill_browser()
# Out:
# 2.9
# 10.6
# 1.7
# 11.0
# 9.0
# 6.8
# 13.4

# %%
# KERNEL 27
from bs4 import BeautifulSoup
import time
from helium import *
driver = start_chrome('https://www.google.com/')
for idx, row in full_clean[337:344].iterrows():
    driver = start_chrome('https://www.google.com/')
    driver.execute_script('window.open('');') #javascript command
    driver.switch_to.window(driver.window_handles[1]) #switch to new window
    driver.get('https://www.google.com/')
    press(row.Player+" basketball reference"); press(ENTER)
    click(Link(row.Player+' Stats, Height'))
    time.sleep(4)
    pagesource = driver.page_source
    soup = BeautifulSoup(driver.page_source, 'lxml')
    table = soup.find('table', {'id': 'per_game'})
    ppg = table.find('tfoot').find('td', {'data-stat': 'pts_per_g'}).text
    print(ppg)
    full_clean.loc[idx, 'NBA_PPG'] = ppg
    driver.close()
    driver.switch_to.window(driver.window_handles[0])
kill_browser()
# Out:
# 5.1
# 3.4
# 6.3
# 19.1
# 5.0
# 6.8
# 25.5

# %%
# just need to clean player names so that theyre the same as on the bball ref
#full_clean = pd.read_csv("full_updated.csv")
full_clean.tail()
# Out:
#      Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0             Player  \
# 339           339           339           339         339   Lindy Waters III
# 340           340           340           340         340     Andrew Wiggins
# 341           341           341           341         341  Lindell Wigginton
# 342           342           342           342         342   Kenrich Williams
# 343           343           343           343         343         Trae Young
#
#     College_Conference          College  College_PPG  NBA_Team NBA_PPG  \
# 339             Big 12   Oklahoma State          5.7   Thunder     6.3
# 340             Big 12           Kansas         17.1  Warriors    19.1
# 341             Big 12       Iowa State         16.4     Bucks     5.0
# 342             Big 12  Texas Christian         14.6   Thunder     6.8
# 343             Big 12         Oklahoma         27.4     Hawks    25.5
#
#      Unnamed: 8  Unnamed: 9  Unnamed: 10
# ...

# %%
fp='/Users/dillonsullivan/Desktop/Syracuse Academics/2023 SPRING/SAL 384/final_project'
full_clean.to_csv(fp+'/full_updated.csv')
